# %%
import pandas as pd

# %%
# import zipfile
# import glob

# files = glob.glob('./*.zip')
# files
# Out:
# ['./chest_xray_full-20230710T210351Z-001.zip']

# %%
# for file in files:
#     print('Unzipping:',file)

#     with zipfile.ZipFile(file, 'r') as zip_ref:
#         zip_ref.extractall('data/raw')
# Out:
# Unzipping: ./chest_xray_full-20230710T210351Z-001.zip

# %%
da = pd.read_pickle("./workflow_data/df_bo_results.pkl")

da.tail(3) #.sort_values('accuracy', ascending = False)
# Out:
#           lr  momentum  conv1out  conv1kernel  filter_size  stride_step
# 67  0.004456  0.964598         8            6            2            4  \
# 68  0.003970  0.879649        11            6            4            3
# 69  0.004305  0.957003         4            5            2            3
#
#     conv2out  conv2_kernel  accuracy
# 67        14             6  0.941847  \
# 68        16             5  0.957811
# 69        13             6  0.922463
#
#                                         accuracy_list
# 67  [0.8973774230330672, 0.9030786773090079, 0.906...  \
# 68  [0.9384264538198404, 0.9395667046750285, 0.952...
# 69  [0.887115165336374, 0.8734321550741163, 0.9179...
#
#                                           recall_list
# 67   [0.93125, 0.9859375, 0.91875, 0.9796875, 0.9625]  \
# 68  [0.971875, 0.953125, 0.9703125, 0.9890625, 0.9...
# 69  [0.909375, 0.99375, 0.965625, 0.98125, 0.9828125]
#
#                                          f2score_list  time_taken
# ...

# %%
da.sort_values('lr', ascending = False) #.head(1)
# Out:
#           lr  momentum  conv1out  conv1kernel  filter_size  stride_step
# 15  0.005000  0.900000         8            4            3            2  \
# 5   0.005000  0.800000         4            4            3            4
# 6   0.005000  0.800000         4            6            2            4
# 7   0.005000  0.950000         4            4            4            2
# 67  0.004456  0.964598         8            6            2            4
# ..       ...       ...       ...          ...          ...          ...
# 42  0.000293  0.972969        10            6            2            3
# 48  0.000291  0.970007        10            4            2            4
# 35  0.000287  0.972967        10            6            2            3
# 49  0.000235  0.866429        14            5            3            3
# 27  0.000149  0.897945         8            4            4            4
#
#     conv2out  conv2_kernel  accuracy
# 15        18             4  0.942987  \
# ...
